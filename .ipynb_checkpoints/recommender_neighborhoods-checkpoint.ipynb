# %%
import pandas as pd
#import cvxpy as cvx
import numpy as np
import scipy.stats as stats
import scipy.spatial.distance as dist
#import nimfa
import time
import matplotlib.pyplot as plt
#from mpltools import style
from scipy.linalg import svd,diagsvd
from scipy import sparse
#from sparsesvd import sparsesvd
from mpltools import style
import scipy.spatial.distance as dist
import scipy.stats as stats
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import manhattan_distances
from scipy.stats.stats import pearsonr
style.use('ggplot')

# %%
df = pd.read_csv('data1.csv')
df.set_index(df['Neighborhood'])
df.head(50)
# Out:
#                      Neighborhood    bars  restaurants  laundry   pizza  \
# 0                   Central Bronx  0.3674       0.5932   0.0000  0.1206
# 1          Bronx Park and Fordham  1.0900       2.5012   1.0502  1.8712
# 2      High Bridge and Morrisania  1.0972       2.3032   0.3006  0.6752
# 3      Hunts Point and Mott Haven  1.3522       2.5278   0.0302  1.7218
# 4       Kingsbridge and Riverdale  0.1136       0.3014   2.9866  0.1572
# 5                 Northeast Bronx  0.8832       2.3460   1.1422  1.4760
# 6                 Southeast Bronx  0.8832       2.3460   1.1422  1.4760
# 7                Central Brooklyn  2.2554       2.5626   1.4340  2.3662
# 8              Southwest Brooklyn  2.4870       2.7846   1.6470  2.0632
# 9                    Borough Park  0.6950       2.3712   0.5116  0.7934
# 10         Canarsie and Flatlands  0.3366       2.1216   0.1358  0.3928
# 11              Southern Brooklyn  0.0000       0.0000   0.0000  0.0000
# 12             Northwest Brooklyn  2.4870       2.7846   1.6470  2.0632
# 13                       Flatbush  2.7194       2.7542   2.1464  2.3446
# 14     East New York and New Lots  0.0000       0.4070   0.0000  0.0000
# 15                     Greenpoint  2.8066       2.9680   2.3124  2.3448
# 16                    Sunset Park  2.3882       2.7632   0.9974  2.1322
# 17      Bushwick and Williamsburg  2.9198       3.3180   1.2038  3.0138
# 18                 Central Harlem  0.0000       0.0000   0.0000  0.0000
# 19            Chelsea and Clinton  0.8688       2.3424   2.1932  0.8620
# 20                    East Harlem  2.8096       2.9794   1.8194  2.4080
# 21  Gramercy Park and Murray Hill  3.3360       3.7516   2.3438  3.2514
# 22     Greenwich Village and Soho  3.4224       4.2702   2.4332  3.3308
# 23                Lower Manhattan  3.1904       3.9474   2.0918  3.3462
# 24                Lower East Side  3.2718       3.6176   2.2530  2.7510
# 25                Upper East Side  3.0774       3.5698   2.3396  2.5306
# 26                Upper West Side  3.0486       3.6388   2.4366  2.6704
# 27  Inwood and Washington Heights  0.1246       0.1246   0.0000  0.0000
# 28               Northeast Queens  2.3248       2.7188   0.4808  2.0948
# 29                   North Queens  2.3248       2.7188   0.4808  2.0948
# 30                 Central Queens  0.0000       0.0000   0.0000  0.0000
# 31                        Jamaica  0.1810       2.7996   2.5590  0.5504
# 32               Northwest Queens  2.3248       2.7188   0.4808  2.0948
# 33            West Central Queens  0.0000       0.0000   0.0000  0.0000
# 34                      Rockaways  0.5356       2.3828   2.5260  0.8618
# 35               Southeast Queens  2.3248       2.7188   0.4808  2.0948
# 36               Southwest Queens  2.3248       2.7188   0.4808  2.0948
# 37                    West Queens  2.3248       2.7188   0.4808  2.0948
# 38                  Port Richmond  0.3308       2.1850   0.1502  0.4678
# 39                    South Shore  0.4698       2.1682   0.2258  0.3204
# 40       Stapleton and St. George  0.0000       0.0000   0.0000  0.0000
# 41                     Mid-Island  0.0000       0.0000   0.0000  0.0000
#
#     hospitals  coffee  boutique  clothing  education    arts
# 0      0.0000  0.1240    0.0000    0.0000     0.0000  0.1962
# 1      0.1358  1.6246    0.3694    0.2814     0.8620  2.0708
# 2      0.0616  0.9702    0.0906    0.8448     0.0604  0.1504
# 3      0.2574  1.5546    0.1364    0.5886     0.2858  0.6204
# 4      0.4822  3.1212    0.3016    0.4526     2.1062  2.8250
# 5      1.4610  1.2800    0.3694    0.2552     0.5758  1.7852
# 6      1.4610  1.2800    0.3694    0.2552     0.5758  1.7852
# 7      0.6908  2.3214    0.1746    1.1776     0.5276  1.4330
# 8      0.0302  2.6906    0.9268    1.4218     0.3992  2.0554
# 9      0.7684  1.6886    0.2862    0.8572     0.0302  0.7224
# 10     0.0754  0.1206    0.0000    0.2558     0.7532  0.6326
# 11     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 12     0.0302  2.6906    0.9268    1.4218     0.3992  2.0554
# 13     2.1718  2.6712    2.0660    2.5960     2.9664  2.9380
# 14     0.0000  0.0302    0.0000    0.0000     0.1530  0.0626
# 15     0.5364  2.9586    2.0944    2.5832     1.8420  2.8606
# 16     0.0316  2.4496    0.0904    0.7094     0.5074  1.4460
# 17     1.0262  2.9012    2.6016    2.6480     2.4086  2.8000
# 18     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 19     2.5870  0.9584    0.1208    0.1508     0.6194  2.9002
# 20     0.6326  2.4526    0.6846    1.7260     1.2816  2.4242
# 21     2.6846  2.9390    2.5496    2.3916     2.7340  2.6254
# 22     2.5992  3.1632    2.6634    2.4864     2.7702  2.6714
# 23     2.5004  3.1882    2.4874    2.7194     2.8674  2.8920
# 24     0.8280  3.0344    2.6750    2.7618     2.8166  2.6662
# 25     2.6612  2.8344    2.3632    2.2070     2.6966  2.6194
# 26     2.6820  3.0678    2.1876    2.2142     2.7970  2.8704
# 27     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 28     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 29     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 30     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 31     0.7880  1.0210    1.2086    2.5674     2.9112  2.9868
# 32     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 33     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 34     0.6372  0.7936    1.2086    2.4930     2.9136  3.0048
# 35     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 36     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 37     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 38     0.1354  0.0000    0.1202    0.1202     0.1504  0.3922
# 39     0.1202  0.3942    0.3010    0.1504     0.3012  0.2300
# 40     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000
# 41     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000

# %%
columns = ['bars','restaurants','laundry','pizza','hospitals','coffee','boutique','clothing','education','arts']
def calculate_similarity(item1, item2):
    dists = []
    for f in columns:
        dists.append(euclidean_distances(df[df['Neighborhood']==item1][f], df[df['Neighborhood']==item2][f])[0][0])
    
    return dists

# %%
simple_distances = []
for i in df['Neighborhood']:
    print "starting", i
    for j in df['Neighborhood']:
        if i != j:
            row = [i, j] + calculate_similarity(i, j)
            simple_distances.append(row)
# Out:
# starting Central Bronx
# starting
#  Bronx Park and Fordham
# starting
#  High Bridge and Morrisania
# starting
#  Hunts Point and Mott Haven
# starting
#  Kingsbridge and Riverdale
# starting
#  Northeast Bronx
# starting
#  Southeast Bronx
# starting
#  Central Brooklyn
# starting
#  Southwest Brooklyn
# starting
#  Borough Park
# starting
#  Canarsie and Flatlands
# starting
#  Southern Brooklyn
# starting
#  Northwest Brooklyn
# starting
#  Flatbush
# starting
#  East New York and New Lots
# starting
#  Greenpoint
# starting
#  Sunset Park
# starting
#  Bushwick and Williamsburg
# starting
#  Central Harlem
# starting
#  Chelsea and Clinton
# starting
#  East Harlem
# starting
#  Gramercy Park and Murray Hill
# starting
#  Greenwich Village and Soho
# starting
#  Lower Manhattan
# starting
#  Lower East Side
# starting
#  Upper East Side
# starting
#  Upper West Side
# starting
#  Inwood and Washington Heights
# starting
#  Northeast Queens
# starting
#  North Queens
# starting
#  Central Queens
# starting
#  Jamaica
# starting
#  Northwest Queens
# starting
#  West Central Queens
# starting
#  Rockaways
# starting
#  Southeast Queens
# starting
#  Southwest Queens
# starting
#  West Queens
# starting
#  Port Richmond
# starting
#  South Shore
# starting
#  Stapleton and St. George
# starting
#  Mid-Island

# %%
cols = ["Neighborhood 1", "Neighborhood 2",'bars','restaurants','laundry','pizza','hospitals','coffee','boutique','clothing','education','arts']
simple_distances = pd.DataFrame(simple_distances, columns=cols)
simple_distances.tail()
# Out:
#      Neighborhood 1            Neighborhood 2    bars  restaurants  laundry  \
# 1717     Mid-Island          Southwest Queens  2.3248       2.7188   0.4808
# 1718     Mid-Island               West Queens  2.3248       2.7188   0.4808
# 1719     Mid-Island             Port Richmond  0.3308       2.1850   0.1502
# 1720     Mid-Island               South Shore  0.4698       2.1682   0.2258
# 1721     Mid-Island  Stapleton and St. George  0.0000       0.0000   0.0000
#
#        pizza  hospitals  coffee  boutique  clothing  education    arts
# 1717  2.0948     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 1718  2.0948     0.0756  2.4170    0.2704    1.1886     0.4818  0.9992
# 1719  0.4678     0.1354  0.0000    0.1202    0.1202     0.1504  0.3922
# 1720  0.3204     0.1202  0.3942    0.3010    0.1504     0.3012  0.2300
# 1721  0.0000     0.0000  0.0000    0.0000    0.0000     0.0000  0.0000

# %%
def calc_distance(dists, z1, z2, weights):
    mask = (dists['Neighborhood 1']==z1) & (dists['Neighborhood 2']==z2)
    row = dists[mask]
    row = row[['bars','restaurants','laundry','pizza','hospitals','coffee','boutique','clothing','education','arts']]
    dist = weights * row
    return dist.sum(axis=1).tolist()[0]

# %%
#Adjust the weights to give priorities to one feature over another. Set preferences based in this manner.
#The output shows the neighborhood most similar to the ones we want based on its similarity to these features.

# %%
def minimum_sim_calc(neighborhood,weights,k):
    m1 = 1000
    l = []
    for j in df['Neighborhood']:
        if j!=neighborhood:
            l.append((calc_distance(simple_distances, neighborhood, j, weights),j))
            #if calc_distance(simple_distances, neighborhood, j, weights)<m1:
            #m1 = min(calc_distance(simple_distances, neighborhood, j, weights),m1)
            #m = (m1,j)
    l =sorted(l,key=lambda x: x[0])
    print "The",k,"most similar neighborhoods to",neighborhood,"are:"
    for i in xrange(k):
        print l[i][1],".The similarity score is =",l[i][0]
    #print "Neighborhood:",neighborhood,"is most similar to Neighborhood:",m[1],".The similarity score is =",m[0]

# %%
weights = [10,10,1,1,1,1,1,1,1,1]
n = "Lower East Side"
k = 7
minimum_sim_calc(n,weights,k)
# Out:
# The 7 most similar neighborhoods to Lower East Side are:
# Gramercy Park and Murray Hill .The similarity score is = 5.1442
# Upper East Side .The similarity score is = 5.7956
# Upper West Side .The similarity score is = 5.8544
# Lower Manhattan .The similarity score is = 7.2012
# Bushwick and Williamsburg .The similarity score is = 8.8884
# Greenwich Village and Soho .The similarity score is = 11.0306
# Greenpoint .The similarity score is = 13.9092

# %%
#Matrix Factorization Method

# %%
import numpy

def matrix_factorization(R, P, Q, K, steps=5000, alpha=0.0002, beta=0.02):
    Q = Q.T
    for step in xrange(steps):
        for i in xrange(len(R)):
            for j in xrange(len(R[i])):
                if R[i][j] > 0:
                    eij = R[i][j] - numpy.dot(P[i,:],Q[:,j])
                    for k in xrange(K):
                        P[i][k] = P[i][k] + alpha * (2 * eij * Q[k][j] - beta * P[i][k])
                        Q[k][j] = Q[k][j] + alpha * (2 * eij * P[i][k] - beta * Q[k][j])
        eR = numpy.dot(P,Q)
        e = 0
        for i in xrange(len(R)):
            for j in xrange(len(R[i])):
                if R[i][j] > 0:
                    e = e + pow(R[i][j] - numpy.dot(P[i,:],Q[:,j]), 2)
                    for k in xrange(K):
                        e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2))
        if e < 0.001:
            break
    return P, Q.T

# %%
cols = ['bars','restaurants','laundry','pizza','hospitals','coffee','boutique','clothing','education','arts']

R = numpy.array(df[cols])

N = len(R)
M = len(R[0])
K = 2

P = numpy.random.rand(N,K)
Q = numpy.random.rand(M,K)

nP, nQ = matrix_factorization(R, P, Q, K)
nR = numpy.dot(nP, nQ.T)

# %%
df1 = pd.DataFrame(data = nR, index = df['Neighborhood'], columns = cols)
df1.head(40)
# Out:
#                                    bars  restaurants   laundry     pizza  \
# Neighborhood
# Central Bronx                  0.151023     0.535226  0.226099  0.211101
# Bronx Park and Fordham         1.271999     2.408847  1.169477  1.356500
# High Bridge and Morrisania     0.754647     1.416676  0.689470  0.802283
# Hunts Point and Mott Haven     1.063725     1.857697  0.923122  1.102918
# Kingsbridge and Riverdale      1.437057     1.782872  0.992668  1.344059
# Northeast Bronx                1.004948     2.566511  1.156187  1.204920
# Southeast Bronx                1.000200     2.576717  1.158542  1.203711
# Central Brooklyn               1.754688     2.584098  1.354612  1.722893
# Southwest Brooklyn             2.075791     2.590238  1.439108  1.944455
# Borough Park                   0.888832     1.872916  0.883599  0.985969
# Canarsie and Flatlands         0.392873     1.379287  0.583605  0.546540
# Southern Brooklyn              0.812937     1.793728  0.836414  0.917992
# Northwest Brooklyn             2.073702     2.595168  1.440299  1.944012
# Flatbush                       2.977791     3.352599  1.937307  2.716457
# East New York and New Lots    -0.003051     0.382354  0.133070  0.074684
# Greenpoint                     2.956221     3.005957  1.810425  2.632049
# Sunset Park                    1.663048     2.455981  1.286261  1.634287
# Bushwick and Williamsburg      3.162481     3.136031  1.908856  2.799696
# Central Harlem                 1.188688     1.868704  0.959022  1.190873
# Chelsea and Clinton            0.895897     3.326495  1.394272  1.282701
# East Harlem                    2.307060     3.042524  1.656751  2.193963
# Gramercy Park and Murray Hill  3.276843     4.083421  2.269840  3.068405
# Greenwich Village and Soho     3.412780     4.366026  2.403634  3.218428
# Lower Manhattan                3.392577     4.168736  2.329387  3.164949
# Lower East Side                3.383204     3.362302  2.044671  2.996584
# Upper East Side                3.030805     3.909199  2.145754  2.864600
# Upper West Side                3.097729     4.088002  2.225511  2.946425
# Inwood and Washington Heights  0.022679     0.193175  0.073442  0.054352
# Northeast Queens               1.696580     2.161994  1.191943  1.598263
# North Queens                   1.697639     2.160146  1.191568  1.598618
# Central Queens                 1.098860     1.718544  0.883419  1.099084
# Jamaica                        1.839288     2.764953  1.439621  1.817259
# Northwest Queens               1.699037     2.156957  1.190810  1.598937
# West Central Queens            2.118042     3.082297  1.622201  2.072253
# Rockaways                      1.891852     2.539471  1.374165  1.808049
# Southeast Queens               1.697177     2.160778  1.191670  1.598427
# Southwest Queens               1.699440     2.156350  1.190701  1.599091
# West Queens                    1.699846     2.155900  1.190647  1.599280
# Port Richmond                  0.362127     1.407018  0.585428  0.531011
# South Shore                    0.406102     1.307407  0.561834  0.541183
#
#                                hospitals    coffee  boutique  clothing  \
# Neighborhood
# Central Bronx                   0.254910  0.208288 -0.010822  0.041531
# Bronx Park and Fordham          1.028554  1.445530  0.512841  0.796804
# High Bridge and Morrisania      0.603591  0.855770  0.307835  0.475373
# Hunts Point and Mott Haven      0.776633  1.185787  0.473966  0.699712
# Kingsbridge and Riverdale       0.661950  1.495042  0.849441  1.100062
# Northeast Bronx                 1.166077  1.239633  0.214291  0.488249
# Southeast Bronx                 1.172466  1.237061  0.206853  0.481187
# Central Brooklyn                1.025200  1.885383  0.920038  1.256503
# Southwest Brooklyn              0.964122  2.161745  1.222701  1.585832
# Borough Park                    0.819790  1.037993  0.303776  0.516386
# Canarsie and Flatlands          0.656169  0.539922 -0.024395  0.110820
# Southern Brooklyn               0.792807  0.961238  0.254607  0.455101
# Northwest Brooklyn              0.967168  2.160679  1.219302  1.582632
# Flatbush                        1.189557  3.047670  1.858505  2.352268
# East New York and New Lots      0.204334  0.053627 -0.112909 -0.084564
# Greenpoint                      1.009185  2.978174  1.937795  2.403874
# Sunset Park                     0.975302  1.787924  0.870020  1.189425
# Bushwick and Williamsburg       1.037155  3.174249  2.095918  2.588560
# Central Harlem                  0.757455  1.294605  0.589272  0.826041
# Chelsea and Clinton             1.592859  1.257878 -0.107770  0.214124
# East Harlem                     1.158760  2.426672  1.311822  1.727654
# Gramercy Park and Murray Hill   1.519018  3.411717  1.931745  2.504571
# Greenwich Village and Soho      1.642351  3.569902  1.979308  2.584364
# Lower Manhattan                 1.541282  3.523549  2.016921  2.605574
# Lower East Side                 1.113482  3.396881  2.240074  2.767652
# Upper East Side                 1.475496  3.175025  1.748613  2.288329
# Upper West Side                 1.557353  3.258738  1.760614  2.319164
# Inwood and Washington Heights   0.098381  0.047872 -0.034081 -0.017784
# Northeast Queens                0.811942  1.773444  0.986402  1.286557
# North Queens                    0.810745  1.774081  0.987938  1.288041
# Central Queens                  0.695450  1.195457  0.547315  0.765523
# Jamaica                         1.104608  1.984562  0.948208  1.305103
# Northwest Queens                0.808766  1.774811  0.990181  1.290160
# West Central Queens             1.217830  2.270373  1.121176  1.524555
# Rockaways                       0.973934  1.996485  1.062920  1.407242
# Southeast Queens                0.811175  1.773777  0.987317  1.287430
# Southwest Queens                0.808362  1.775067  0.990737  1.290703
# West Queens                     0.808041  1.775349  0.991251  1.291217
# Port Richmond                   0.677106  0.517625 -0.061524  0.073256
# South Shore                     0.615219  0.540696  0.008829  0.139749
#
#                                education      arts
# Neighborhood
# Central Bronx                   0.091623  0.316514
# Bronx Park and Fordham          0.876431  1.578308
# High Bridge and Morrisania      0.520587  0.929930
# Hunts Point and Mott Haven      0.740746  1.238677
# Kingsbridge and Riverdale       1.036986  1.296851
# Northeast Bronx                 0.659329  1.590650
# Southeast Bronx                 0.655100  1.594705
# Central Brooklyn                1.245875  1.794441
# Southwest Brooklyn              1.497155  1.881000
# Borough Park                    0.602957  1.201149
# Canarsie and Flatlands          0.239001  0.816620
# Southern Brooklyn               0.547445  1.140415
# Northwest Brooklyn              1.495272  1.883012
# Flatbush                        2.165838  2.510193
# East New York and New Lots     -0.021468  0.197304
# Greenpoint                      2.166233  2.324997
# Sunset Park                     1.180467  1.704268
# Bushwick and Williamsburg       2.321349  2.445946
# Central Harlem                  0.838106  1.276828
# Chelsea and Clinton             0.535969  1.956080
# East Harlem                     1.655789  2.175381
# Gramercy Park and Murray Hill   2.363683  2.966482
# Greenwich Village and Soho      2.456091  3.148197
# Lower Manhattan                 2.450105  3.040735
# Lower East Side                 2.482997  2.620490
# Upper East Side                 2.179604  2.812331
# Upper West Side                 2.223119  2.922347
# Inwood and Washington Heights   0.008131  0.105972
# Northeast Queens                1.221408  1.560662
# North Queens                    1.222330  1.559979
# Central Queens                  0.775217  1.175706
# Jamaica                         1.303137  1.910109
# Northwest Queens                1.223585  1.558690
# West Central Queens             1.505708  2.146906
# Rockaways                       1.355570  1.806936
# Southeast Queens                1.221936  1.560186
# Southwest Queens                1.223930  1.558480
# West Queens                     1.224271  1.558352
# Port Richmond                   0.213527  0.823003
# South Shore                     0.252952  0.782814

# %%
df1.head(10)
# Out:
#                                 bars  restaurants   laundry     pizza  \
# Neighborhood
# Central Bronx               0.151023     0.535226  0.226099  0.211101
# Bronx Park and Fordham      1.271999     2.408847  1.169477  1.356500
# High Bridge and Morrisania  0.754647     1.416676  0.689470  0.802283
# Hunts Point and Mott Haven  1.063725     1.857697  0.923122  1.102918
# Kingsbridge and Riverdale   1.437057     1.782872  0.992668  1.344059
# Northeast Bronx             1.004948     2.566511  1.156187  1.204920
# Southeast Bronx             1.000200     2.576717  1.158542  1.203711
# Central Brooklyn            1.754688     2.584098  1.354612  1.722893
# Southwest Brooklyn          2.075791     2.590238  1.439108  1.944455
# Borough Park                0.888832     1.872916  0.883599  0.985969
#
#                             hospitals    coffee  boutique  clothing  \
# Neighborhood
# Central Bronx                0.254910  0.208288 -0.010822  0.041531
# Bronx Park and Fordham       1.028554  1.445530  0.512841  0.796804
# High Bridge and Morrisania   0.603591  0.855770  0.307835  0.475373
# Hunts Point and Mott Haven   0.776633  1.185787  0.473966  0.699712
# Kingsbridge and Riverdale    0.661950  1.495042  0.849441  1.100062
# Northeast Bronx              1.166077  1.239633  0.214291  0.488249
# Southeast Bronx              1.172466  1.237061  0.206853  0.481187
# Central Brooklyn             1.025200  1.885383  0.920038  1.256503
# Southwest Brooklyn           0.964122  2.161745  1.222701  1.585832
# Borough Park                 0.819790  1.037993  0.303776  0.516386
#
#                             education      arts
# Neighborhood
# Central Bronx                0.091623  0.316514
# Bronx Park and Fordham       0.876431  1.578308
# High Bridge and Morrisania   0.520587  0.929930
# Hunts Point and Mott Haven   0.740746  1.238677
# Kingsbridge and Riverdale    1.036986  1.296851
# Northeast Bronx              0.659329  1.590650
# Southeast Bronx              0.655100  1.594705
# Central Brooklyn             1.245875  1.794441
# Southwest Brooklyn           1.497155  1.881000
# Borough Park                 0.602957  1.201149

# %%
df.head(10)
# Out:
#                  Neighborhood    bars  restaurants  laundry   pizza  \
# 0               Central Bronx  0.3674       0.5932   0.0000  0.1206
# 1      Bronx Park and Fordham  1.0900       2.5012   1.0502  1.8712
# 2  High Bridge and Morrisania  1.0972       2.3032   0.3006  0.6752
# 3  Hunts Point and Mott Haven  1.3522       2.5278   0.0302  1.7218
# 4   Kingsbridge and Riverdale  0.1136       0.3014   2.9866  0.1572
# 5             Northeast Bronx  0.8832       2.3460   1.1422  1.4760
# 6             Southeast Bronx  0.8832       2.3460   1.1422  1.4760
# 7            Central Brooklyn  2.2554       2.5626   1.4340  2.3662
# 8          Southwest Brooklyn  2.4870       2.7846   1.6470  2.0632
# 9                Borough Park  0.6950       2.3712   0.5116  0.7934
#
#    hospitals  coffee  boutique  clothing  education    arts
# 0     0.0000  0.1240    0.0000    0.0000     0.0000  0.1962
# 1     0.1358  1.6246    0.3694    0.2814     0.8620  2.0708
# 2     0.0616  0.9702    0.0906    0.8448     0.0604  0.1504
# 3     0.2574  1.5546    0.1364    0.5886     0.2858  0.6204
# 4     0.4822  3.1212    0.3016    0.4526     2.1062  2.8250
# 5     1.4610  1.2800    0.3694    0.2552     0.5758  1.7852
# 6     1.4610  1.2800    0.3694    0.2552     0.5758  1.7852
# 7     0.6908  2.3214    0.1746    1.1776     0.5276  1.4330
# 8     0.0302  2.6906    0.9268    1.4218     0.3992  2.0554
# 9     0.7684  1.6886    0.2862    0.8572     0.0302  0.7224

# %%
def minimum_sim_calc1(neighborhood,weights,k):
    m1 = 1000
    l = []
    for j in df1.index:
        if j!=neighborhood:
            l.append((calc_distance(simple_distances, neighborhood, j, weights),j))
            #if calc_distance(simple_distances, neighborhood, j, weights)<m1:
            #m1 = min(calc_distance(simple_distances, neighborhood, j, weights),m1)
            #m = (m1,j)
    l =sorted(l,key=lambda x: x[0])
    print "The",k,"most similar neighborhoods to",neighborhood,"are:"
    for i in xrange(k):
        print l[i][1],".The similarity score is =",l[i][0]
    #print "Neighborhood:",neighborhood,"is most similar to Neighborhood:",m[1],".The similarity score is =",m[0]

# %%
weights = [10,10,1,1,1,1,1,1,1,1]
n = "Central Bronx"
k = 7
minimum_sim_calc1(n,weights,k)
# Out:
# The 7 most similar neighborhoods to Central Bronx are:
# East New York and New Lots .The similarity score is = 6.037
# Inwood and Washington Heights .The similarity score is = 7.5548
# Southern Brooklyn .The similarity score is = 10.0468
# Central Harlem .The similarity score is = 10.0468
# Central Queens .The similarity score is = 10.0468
# West Central Queens .The similarity score is = 10.0468
# Stapleton and St. George .The similarity score is = 10.0468
